# %%
from pathlib import Path
import os

# %%
requirements_file = Path(os.getcwd()).parent / "requirements.txt"
# !pip install -r {str(requirements_file)}
# Out:
# Requirement already satisfied: opencv-python==4.13.0.92 in /opt/conda/lib/python3.11/site-packages (from -r /home/jovyan/work/requirements.txt (line 1)) (4.13.0.92)
# Requirement already satisfied: matplotlib==3.11.0 in /opt/conda/lib/python3.11/site-packages (from -r /home/jovyan/work/requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: ultralytics>=8.4.0 in /opt/conda/lib/python3.11/site-packages (from -r /home/jovyan/work/requirements.txt (line 3)) (8.4.66)
# Requirement already satisfied: numpy>=2 in /opt/conda/lib/python3.11/site-packages (from opencv-python==4.13.0.92->-r /home/jovyan/work/requirements.txt (line 1)) (2.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (10.1.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2.12.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (0.27.0)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.41.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2.0.20)
# Requirement already satisfied: polars-runtime-32==1.41.2 in /opt/conda/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.41.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.11.0->-r /home/jovyan/work/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (68.2.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2023.9.2)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /opt/conda/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics>=8.4.0->-r /home/jovyan/work/requirements.txt (line 3)) (2.1.3)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
notebook_path = Path(os.getcwd())
dataset_path = notebook_path.parent / "data"

train_imgs = dataset_path / "train/train/images"
val_imgs = dataset_path / "val/val/images"
test_imgs = dataset_path / "test/test/images"

train_mark = dataset_path / "train/train/labels"
val_mark = dataset_path / "val/val/labels"
test_mark = dataset_path / "test/test/labels"

print(f'Путь до обучающих изображений:{train_imgs}', 
      f'Путь до валидационных изображений:{val_imgs}', 
      f'Путь до тестовых изображений:{test_imgs}', 
      f'Путь до обучающих разметок:{train_mark}', 
      f'Путь до валидационных разметок:{val_mark}', 
      f'Путь до тестовых разметок:{test_mark}',
      sep='\n')
# Out:
# Путь до обучающих изображений:/home/jovyan/work/data/train/train/images
# Путь до валидационных изображений:/home/jovyan/work/data/val/val/images
# Путь до тестовых изображений:/home/jovyan/work/data/test/test/images
# Путь до обучающих разметок:/home/jovyan/work/data/train/train/labels
# Путь до валидационных разметок:/home/jovyan/work/data/val/val/labels
# Путь до тестовых разметок:/home/jovyan/work/data/test/test/labels

# %%
#Просмотр объема данных
train_images = list((train_imgs).glob("*"))
val_images = list((val_imgs).glob("*"))
test_images = list((test_imgs).glob("*"))

print(f"Длина обучающей выборки: {len(train_images)}")
print(f"Длина валидационной выборки: {len(val_images)}")
print(f"Длина тестовая выборки: {len(test_images)}")
# Out:
# Длина обучающей выборки: 20505
# Длина валидационной выборки: 2563
# Длина тестовая выборки: 2564

# %%
image = cv2.imread(train_imgs / "1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
with open(train_mark / "1.txt", "r") as f:
    labels = f.readlines()

for label in labels:
    print(label.strip())
# Out:
# 0 0.751250 0.735132 0.179167 0.109031
# 0 0.807083 0.302863 0.044167 0.017621

# %%
h, w, _ = image.shape

with open(train_mark / "1.txt", "r") as f:
    labels = f.readlines()

for label in labels:
    cls, x_center, y_center, box_w, box_h = map(float, label.split())

    x_center *= w
    y_center *= h
    box_w *= w
    box_h *= h 

    x1 = int(x_center - box_w / 2)
    y1 = int(y_center - box_h / 2)
    x2 = int(x_center + box_w / 2)
    y2 = int(y_center + box_h / 2)

    cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)

plt.figure(figsize=(10, 6))
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
train_files = set(train_images)
val_files = set(val_images)
test_files = set(test_images)

assert len(train_files & val_files) == 0
assert len(train_files & test_files) == 0
assert len(val_files & test_files) == 0

print("Утечки не обнаружено")
# Out:
# Утечки не обнаружено
